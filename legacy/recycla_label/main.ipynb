# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Before...
# Update analysis_Tools_config_default.yaml date range
# > recycla download-documents

# %%
from recycla import DATA_PATH
from main import generate_data_pkl, get_pkl
import tkinter as tk
from gui import build_gui
start_path = DATA_PATH / 'pi_data' / 'video' / '2025-07-23_2025-07-31'
if True:
    data = generate_data_pkl(start_path)
else:
    data = get_pkl()

# %%
# Only create the window once
window = tk.Tk()
window.title("Recycla Label")
window.geometry("2200x1400")
build_gui(window, data, 0)
window.mainloop()

# %%
print(data[list(data.keys())[0]].keys())
print(data[list(data.keys())[0]]["model"])
print(data[list(data.keys())[0]]["model"].class_id)
print(data[list(data.keys())[0]]["model"].user_ground_truth)
print(data[list(data.keys())[0]]["gt_sub"])
print(data[list(data.keys())[0]]["gt_mat"])
print(data[list(data.keys())[0]]["model"].valid_frames)

# %%
print(data[list(data.keys())[10]].keys())
print(data[list(data.keys())[10]]["id"])
print(data[list(data.keys())[10]]["h264_path"])

# %%
#bads = [27,28,31,111,113,114]
bads = [126,132,142,146,153,156,162,164,172,174,208]
for i in bads:
    print(data[list(data.keys())[i-1]]["h264_path"])

# %%
import shutil
import os

files = [
#r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\metal\smxSZGnCFNKQRaJKRLXy.h264",
#r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\metal\T2sNr1GzbrIsOBGhoNuH.h264",
#r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\metal, aluminum_can\9016kC8YlHpalZkIKK39.h264",
#r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\mixed, tetra_pak\MAW4JULgHP4mdKBUua3v.h264",
#r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\mixed, tetra_pak\OhN8HDSw42wh4JKxPisg.h264",
#r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\mixed, tetra_pak\QFOypfaziFSV9neQPHw0.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper\bGqP6GLyadngt1kUmQc1.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper\Gx7ixElxeTXkxwdYInyw.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper\mQQfZfolGBtN7Lk3pnAU.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper\pxAkUrcjevVv1MpD0m2f.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper\XzYt8DAVt2DNeZoXIJBF.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper, corrugated_cardboard\2qO4bnGqmqGYW4yGzzmY.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper, corrugated_cardboard\dLotiJesxjwZwWR0yKBG.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper, corrugated_cardboard\fpyW7cUrhc92JPLyxZL4.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper, corrugated_cardboard\nccfwC2CsQJIkIkRjHD4.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper, corrugated_cardboard\rHlpAXQEcB5dR3Cn1Xf2.h264",
r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\video\2025-06-27_2025-07-06\paper, paperboard\Ps2H5fOyt2cxl8XbuToz.h264",
]

out_dir = r"C:\Users\chris\OneDrive\Documents\src\recycla\data\pi_data\test\hard_false_positives2"
os.makedirs(out_dir, exist_ok=True)
for file in files:
    shutil.copy(file, out_dir)
